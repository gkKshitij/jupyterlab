# %% [markdown]
# Flow shop [premptive]

# %%
process = [[2, 3, 5],[0, 3, 2]] 

tt=[] #total time / worst case

#making of taask flag
ti = [] #progress of the task
m=len(process)
n=len(process[0])

for i in range(m): 
    ti.append([]) 
    for j in range(n):
        if j==(n-1):
            ti[i].append(2)
        else:
            ti[i].append(0)
print(ti) 

#making of process flag
po=[] #processor occupied by process n
for i in range (len(process[0])):
    po.append(9)
#po[0]=1
print(po)

# ti=[[0, 0, 2],[0, 0, 2]]
# print(ti)

for list in process:
    for number in list:
        tt.append(number)
#print(tt)
total=0
for ele in range(0, len(tt)): 
    total = total + tt[ele] 

#printing total value 
print("Total: ", total) 
#non premptive = 11
#premptive = 12
# Out:
# [[0, 0, 2], [0, 0, 2]]
# [9, 9, 9]
# Total:  15

# %%
def flowshop():
    time = 0
    x=0
    y=0
    k=0
    
    for time in range(total):
        print("\n")
        print("\n")
        print(f"time=",time+1)
        count=0

        for x in range(len(process)):
            print("\n")
            print(f"x={x}")

            for y in range(len(process[0])):
                print(f"y={y+1}")
                print("po=",po)
                print("ti=",ti)
                print(f"process={process}")
                print(f"dealing with process: process[{x+1}],[{y+1}]")
                if process[x][y]!=0:
                    if po[y]>=x and ti[x][y-1]==2:
                        print(f"process[{x+1}][{y+1}] before={process[x][y]}")
                        process[x][y] = process[x][y] - 1
                        print(f"process[{x+1}][{y+1}] after={process[x][y]}")
                        ti[x][y]=1
                        print("ti=",ti)
                        print(process)
                        po[y]=x
                        print(f"po[{y+1}]={po[y]+1}")
                    else:
                        print("nothing executed")
                else:
                    print(f"process task [{x+1}],[{y+1}] is completed")
                    po[y]=9
                    count=count+1
                    ti[x][y]=2
                    #break

        if count==len(tt):
            print("time required",time)
            break

# %%
flowshop()
# Out:
# time= 1
#
#
# x=0
# y=1
# po= [9, 9, 9]
# ti= [[0, 0, 2], [0, 0, 2]]
# process=[[2, 3, 5], [0, 3, 2]]
# dealing with process: process[1],[1]
# process[1][1] before=2
# process[1][1] after=1
# ti= [[1, 0, 2], [0, 0, 2]]
# [[1, 3, 5], [0, 3, 2]]
# po[1]=1
# y=2
# po= [0, 9, 9]
# ti= [[1, 0, 2], [0, 0, 2]]
# process=[[1, 3, 5], [0, 3, 2]]
# dealing with process: process[1],[2]
# nothing executed
# y=3
# po= [0, 9, 9]
# ti= [[1, 0, 2], [0, 0, 2]]
# process=[[1, 3, 5], [0, 3, 2]]
# dealing with process: process[1],[3]
# nothing executed
#
#
# x=1
# y=1
# po= [0, 9, 9]
# ti= [[1, 0, 2], [0, 0, 2]]
# process=[[1, 3, 5], [0, 3, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 9, 9]
# ti= [[1, 0, 2], [2, 0, 2]]
# process=[[1, 3, 5], [0, 3, 2]]
# dealing with process: process[2],[2]
# process[2][2] before=3
# process[2][2] after=2
# ti= [[1, 0, 2], [2, 1, 2]]
# [[1, 3, 5], [0, 2, 2]]
# po[2]=2
# y=3
# po= [9, 1, 9]
# ti= [[1, 0, 2], [2, 1, 2]]
# process=[[1, 3, 5], [0, 2, 2]]
# dealing with process: process[2],[3]
# nothing executed
#
#
#
#
# time= 2
#
#
# x=0
# y=1
# po= [9, 1, 9]
# ti= [[1, 0, 2], [2, 1, 2]]
# process=[[1, 3, 5], [0, 2, 2]]
# dealing with process: process[1],[1]
# process[1][1] before=1
# process[1][1] after=0
# ti= [[1, 0, 2], [2, 1, 2]]
# [[0, 3, 5], [0, 2, 2]]
# po[1]=1
# y=2
# po= [0, 1, 9]
# ti= [[1, 0, 2], [2, 1, 2]]
# process=[[0, 3, 5], [0, 2, 2]]
# dealing with process: process[1],[2]
# nothing executed
# y=3
# po= [0, 1, 9]
# ti= [[1, 0, 2], [2, 1, 2]]
# process=[[0, 3, 5], [0, 2, 2]]
# dealing with process: process[1],[3]
# nothing executed
#
#
# x=1
# y=1
# po= [0, 1, 9]
# ti= [[1, 0, 2], [2, 1, 2]]
# process=[[0, 3, 5], [0, 2, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 1, 9]
# ti= [[1, 0, 2], [2, 1, 2]]
# process=[[0, 3, 5], [0, 2, 2]]
# dealing with process: process[2],[2]
# process[2][2] before=2
# process[2][2] after=1
# ti= [[1, 0, 2], [2, 1, 2]]
# [[0, 3, 5], [0, 1, 2]]
# po[2]=2
# y=3
# po= [9, 1, 9]
# ti= [[1, 0, 2], [2, 1, 2]]
# process=[[0, 3, 5], [0, 1, 2]]
# dealing with process: process[2],[3]
# nothing executed
#
#
#
#
# time= 3
#
#
# x=0
# y=1
# po= [9, 1, 9]
# ti= [[1, 0, 2], [2, 1, 2]]
# process=[[0, 3, 5], [0, 1, 2]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 1, 9]
# ti= [[2, 0, 2], [2, 1, 2]]
# process=[[0, 3, 5], [0, 1, 2]]
# dealing with process: process[1],[2]
# process[1][2] before=3
# process[1][2] after=2
# ti= [[2, 1, 2], [2, 1, 2]]
# [[0, 2, 5], [0, 1, 2]]
# po[2]=1
# y=3
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 2, 5], [0, 1, 2]]
# dealing with process: process[1],[3]
# nothing executed
#
#
# x=1
# y=1
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 2, 5], [0, 1, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 2, 5], [0, 1, 2]]
# dealing with process: process[2],[2]
# nothing executed
# y=3
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 2, 5], [0, 1, 2]]
# dealing with process: process[2],[3]
# nothing executed
#
#
#
#
# time= 4
#
#
# x=0
# y=1
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 2, 5], [0, 1, 2]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 2, 5], [0, 1, 2]]
# dealing with process: process[1],[2]
# process[1][2] before=2
# process[1][2] after=1
# ti= [[2, 1, 2], [2, 1, 2]]
# [[0, 1, 5], [0, 1, 2]]
# po[2]=1
# y=3
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 1, 5], [0, 1, 2]]
# dealing with process: process[1],[3]
# nothing executed
#
#
# x=1
# y=1
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 1, 5], [0, 1, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 1, 5], [0, 1, 2]]
# dealing with process: process[2],[2]
# nothing executed
# y=3
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 1, 5], [0, 1, 2]]
# dealing with process: process[2],[3]
# nothing executed
#
#
#
#
# time= 5
#
#
# x=0
# y=1
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 1, 5], [0, 1, 2]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 1, 5], [0, 1, 2]]
# dealing with process: process[1],[2]
# process[1][2] before=1
# process[1][2] after=0
# ti= [[2, 1, 2], [2, 1, 2]]
# [[0, 0, 5], [0, 1, 2]]
# po[2]=1
# y=3
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 0, 5], [0, 1, 2]]
# dealing with process: process[1],[3]
# nothing executed
#
#
# x=1
# y=1
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 0, 5], [0, 1, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 0, 5], [0, 1, 2]]
# dealing with process: process[2],[2]
# nothing executed
# y=3
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 0, 5], [0, 1, 2]]
# dealing with process: process[2],[3]
# nothing executed
#
#
#
#
# time= 6
#
#
# x=0
# y=1
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 0, 5], [0, 1, 2]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 0, 9]
# ti= [[2, 1, 2], [2, 1, 2]]
# process=[[0, 0, 5], [0, 1, 2]]
# dealing with process: process[1],[2]
# process task [1],[2] is completed
# y=3
# po= [9, 9, 9]
# ti= [[2, 2, 2], [2, 1, 2]]
# process=[[0, 0, 5], [0, 1, 2]]
# dealing with process: process[1],[3]
# process[1][3] before=5
# process[1][3] after=4
# ti= [[2, 2, 1], [2, 1, 2]]
# [[0, 0, 4], [0, 1, 2]]
# po[3]=1
#
#
# x=1
# y=1
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 1, 2]]
# process=[[0, 0, 4], [0, 1, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 1, 2]]
# process=[[0, 0, 4], [0, 1, 2]]
# dealing with process: process[2],[2]
# process[2][2] before=1
# process[2][2] after=0
# ti= [[2, 2, 1], [2, 1, 2]]
# [[0, 0, 4], [0, 0, 2]]
# po[2]=2
# y=3
# po= [9, 1, 0]
# ti= [[2, 2, 1], [2, 1, 2]]
# process=[[0, 0, 4], [0, 0, 2]]
# dealing with process: process[2],[3]
# nothing executed
#
#
#
#
# time= 7
#
#
# x=0
# y=1
# po= [9, 1, 0]
# ti= [[2, 2, 1], [2, 1, 2]]
# process=[[0, 0, 4], [0, 0, 2]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 1, 0]
# ti= [[2, 2, 1], [2, 1, 2]]
# process=[[0, 0, 4], [0, 0, 2]]
# dealing with process: process[1],[2]
# process task [1],[2] is completed
# y=3
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 1, 2]]
# process=[[0, 0, 4], [0, 0, 2]]
# dealing with process: process[1],[3]
# process[1][3] before=4
# process[1][3] after=3
# ti= [[2, 2, 1], [2, 1, 2]]
# [[0, 0, 3], [0, 0, 2]]
# po[3]=1
#
#
# x=1
# y=1
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 1, 2]]
# process=[[0, 0, 3], [0, 0, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 1, 2]]
# process=[[0, 0, 3], [0, 0, 2]]
# dealing with process: process[2],[2]
# process task [2],[2] is completed
# y=3
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 3], [0, 0, 2]]
# dealing with process: process[2],[3]
# nothing executed
#
#
#
#
# time= 8
#
#
# x=0
# y=1
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 3], [0, 0, 2]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 3], [0, 0, 2]]
# dealing with process: process[1],[2]
# process task [1],[2] is completed
# y=3
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 3], [0, 0, 2]]
# dealing with process: process[1],[3]
# process[1][3] before=3
# process[1][3] after=2
# ti= [[2, 2, 1], [2, 2, 2]]
# [[0, 0, 2], [0, 0, 2]]
# po[3]=1
#
#
# x=1
# y=1
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 2], [0, 0, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 2], [0, 0, 2]]
# dealing with process: process[2],[2]
# process task [2],[2] is completed
# y=3
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 2], [0, 0, 2]]
# dealing with process: process[2],[3]
# nothing executed
#
#
#
#
# time= 9
#
#
# x=0
# y=1
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 2], [0, 0, 2]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 2], [0, 0, 2]]
# dealing with process: process[1],[2]
# process task [1],[2] is completed
# y=3
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 2], [0, 0, 2]]
# dealing with process: process[1],[3]
# process[1][3] before=2
# process[1][3] after=1
# ti= [[2, 2, 1], [2, 2, 2]]
# [[0, 0, 1], [0, 0, 2]]
# po[3]=1
#
#
# x=1
# y=1
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 1], [0, 0, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 1], [0, 0, 2]]
# dealing with process: process[2],[2]
# process task [2],[2] is completed
# y=3
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 1], [0, 0, 2]]
# dealing with process: process[2],[3]
# nothing executed
#
#
#
#
# time= 10
#
#
# x=0
# y=1
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 1], [0, 0, 2]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 1], [0, 0, 2]]
# dealing with process: process[1],[2]
# process task [1],[2] is completed
# y=3
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 1], [0, 0, 2]]
# dealing with process: process[1],[3]
# process[1][3] before=1
# process[1][3] after=0
# ti= [[2, 2, 1], [2, 2, 2]]
# [[0, 0, 0], [0, 0, 2]]
# po[3]=1
#
#
# x=1
# y=1
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 0], [0, 0, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 0], [0, 0, 2]]
# dealing with process: process[2],[2]
# process task [2],[2] is completed
# y=3
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 0], [0, 0, 2]]
# dealing with process: process[2],[3]
# nothing executed
#
#
#
#
# time= 11
#
#
# x=0
# y=1
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 0], [0, 0, 2]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 0], [0, 0, 2]]
# dealing with process: process[1],[2]
# process task [1],[2] is completed
# y=3
# po= [9, 9, 0]
# ti= [[2, 2, 1], [2, 2, 2]]
# process=[[0, 0, 0], [0, 0, 2]]
# dealing with process: process[1],[3]
# process task [1],[3] is completed
#
#
# x=1
# y=1
# po= [9, 9, 9]
# ti= [[2, 2, 2], [2, 2, 2]]
# process=[[0, 0, 0], [0, 0, 2]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 9, 9]
# ti= [[2, 2, 2], [2, 2, 2]]
# process=[[0, 0, 0], [0, 0, 2]]
# dealing with process: process[2],[2]
# process task [2],[2] is completed
# y=3
# po= [9, 9, 9]
# ti= [[2, 2, 2], [2, 2, 2]]
# process=[[0, 0, 0], [0, 0, 2]]
# dealing with process: process[2],[3]
# process[2][3] before=2
# process[2][3] after=1
# ti= [[2, 2, 2], [2, 2, 1]]
# [[0, 0, 0], [0, 0, 1]]
# po[3]=2
#
#
#
#
# time= 12
#
#
# x=0
# y=1
# po= [9, 9, 1]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 1]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 9, 1]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 1]]
# dealing with process: process[1],[2]
# process task [1],[2] is completed
# y=3
# po= [9, 9, 1]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 1]]
# dealing with process: process[1],[3]
# process task [1],[3] is completed
#
#
# x=1
# y=1
# po= [9, 9, 9]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 1]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 9, 9]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 1]]
# dealing with process: process[2],[2]
# process task [2],[2] is completed
# y=3
# po= [9, 9, 9]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 1]]
# dealing with process: process[2],[3]
# process[2][3] before=1
# process[2][3] after=0
# ti= [[2, 2, 2], [2, 2, 1]]
# [[0, 0, 0], [0, 0, 0]]
# po[3]=2
#
#
#
#
# time= 13
#
#
# x=0
# y=1
# po= [9, 9, 1]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 0]]
# dealing with process: process[1],[1]
# process task [1],[1] is completed
# y=2
# po= [9, 9, 1]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 0]]
# dealing with process: process[1],[2]
# process task [1],[2] is completed
# y=3
# po= [9, 9, 1]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 0]]
# dealing with process: process[1],[3]
# process task [1],[3] is completed
#
#
# x=1
# y=1
# po= [9, 9, 9]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 0]]
# dealing with process: process[2],[1]
# process task [2],[1] is completed
# y=2
# po= [9, 9, 9]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 0]]
# dealing with process: process[2],[2]
# process task [2],[2] is completed
# y=3
# po= [9, 9, 9]
# ti= [[2, 2, 2], [2, 2, 1]]
# process=[[0, 0, 0], [0, 0, 0]]
# dealing with process: process[2],[3]
# process task [2],[3] is completed
# time required 12
